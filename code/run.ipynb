# %%
# !python3 main.py train cifar-10-batches-py --result_dir results
# Out:
# train cifar-10-batches-py
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (convStack1): Sequential(
#     (0): ImprovedBlock(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (projection): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ImprovedBlock(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python3 main.py test cifar-10-batches-py --result_dir results
# Out:
# test cifar-10-batches-py
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (convStack1): Sequential(
#     (0): ImprovedBlock(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (projection): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ImprovedBlock(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python3 main.py predict private_test_images_2024.npy --result_dir results/predictions.npy
# Out:
# predict private_test_images_2024.npy
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (convStack1): Sequential(
#     (0): ImprovedBlock(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (projection): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ImprovedBlock(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import numpy as np
x = np.load('results/predictions.npy')
print(x)
# Out:
# [[3.7566337e-04 1.6365287e-06 9.5031686e-07 ... 6.1743179e-09
#   9.9962139e-01 1.6576102e-07]
#  [8.4374221e-08 1.0573573e-06 5.0412911e-08 ... 5.1310625e-08
#   6.5002414e-06 1.6614563e-07]
#  [7.4764300e-10 2.6714843e-04 1.2058985e-08 ... 1.8230936e-10
#   1.0499227e-09 9.9973279e-01]
#  ...
#  [1.9463823e-04 8.8564658e-01 4.2878928e-05 ... 7.3846400e-05
#   4.9672474e-04 1.1349311e-01]
#  [1.6966886e-06 1.3428353e-06 2.2370933e-04 ... 6.8296162e-05
#   3.0068873e-07 7.9486938e-07]
#  [3.8592550e-03 3.3211511e-06 1.5791805e-06 ... 2.6656349e-07
#   9.9612409e-01 7.8285592e-07]]

# %%
import numpy as np
x = np.load('results/predictions.npy')
print(x[1000])
# Out:
# [8.4237648e-08 2.1175345e-07 4.4005020e-07 2.0345262e-05 4.9425475e-04
#  2.6846386e-04 2.8852619e-07 9.9921572e-01 2.7223420e-08 1.6842478e-07]
